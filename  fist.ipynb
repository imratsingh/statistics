# %%
# MEASURE OF CETERTENDENCY
# (1) mean 
# (2) median
# (3) mode

# %% [markdown]
# # measure of centertendency

# %%
# ----------------------------- how to find mean ---------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\imrat\OneDrive\Desktop\data_science_all_uses_items\Data_set\titanic.csv")

# %%
dataset.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
# we wont to avg age

# %%
dataset["age"].mean()
# Out:
# 29.69911764705882

# %%
np.mean(dataset["age"])
# Out:
# 29.69911764705882

# %%
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.histplot(x="age",data = dataset,bins=[i for i in range(0,81,10)])
plt.show()

# %% [markdown]
# # median

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\imrat\OneDrive\Desktop\data_science_all_uses_items\Data_set\titanic.csv")

# %%
dataset.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
dataset["age"].median()
# Out:
# 29.69911764705882

# %%
dataset.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
dataset["age"].fillna(dataset["age"].mean(),inplace=True)

# %%
np.median(dataset["age"])
# Out:
# 29.69911764705882

# %%
dataset.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
dataset["fare"].median()
# Out:
# 14.4542

# %%
np.median(dataset["fare"])
# Out:
# 14.4542

# %%
sns.histplot(x="fare",data=dataset,bins=[i for i in range(0,81,10)])
plt.show()

# %% [markdown]
# # mode

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\imrat\OneDrive\Desktop\data_science_all_uses_items\Data_set\titanic.csv")

# %%
dataset["fare"].mode()[0]
# Out:
# 8.05

# %%
dataset["fare"].value_counts()
# Out:
# fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
sns.histplot(x="fare",data=dataset,bins=[i for i in range(0,81,10)])
plt.show()

# %% [markdown]
# # measure of variability

# %%
# these are  used for check data spridness

# %% [markdown]
# -- range

# %%
import numpy as np
import pandas as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\imrat\OneDrive\Desktop\data_science_all_uses_items\Data_set\titanic.csv")

# %%
dataset.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
min_r = dataset["age"].min()

# %%
max_r = dataset["age"].max()

# %%
min_r,max_r
# Out:
# (0.42, 80.0)

# %%
range = max_r - min_r
range
# Out:
# 79.58

# %% [markdown]
# -- mean absolute deviation
# # like if we have two dataset and we choise which dataset we won'd so fistly find mean absolute division which is less sprid take that

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
A = np.array([75,65,73,68,72,67])
B = np.array([90,47,48,96,93,51])
no = np.array([1,2,3,4,5,6])

# %%
mean_B = np.mean(B)
mean
mean_A = np.mean(A)
mean_A
# Out:
# 70.0

# %%
mad_A = np.sum(np.abs(A - mean_A))/len(A)
mad_A
mad_B = np.sum(np.abs(B - mean_B))/len(B)
mad_B
# Out:
# 22.166666666666668

# %%
mad_A,mad_B
# Out:
# (3.3333333333333335, 22.166666666666668)

# %%
plt.figure(figsize=(10,3))
plt.scatter(A,no,label="A")
plt.scatter(B,no,color="red",label="B")
plt.plot([70,70,70,70,70,70],no,c="blue",label="B")
plt.legend()
plt.show()

# %%
-- standard deviation and variation
# when we find mean absolute deviation and both are same then we find standard
# deviation or variance which one give less value then take that

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\imrat\OneDrive\Desktop\data_science_all_uses_items\Data_set\titanic.csv")

# %%
A = np.array([75,65,73,68,72,67])
B = np.array([90,47,48,96,93,51])

# %%
np.std(A),np.std(B)
# Out:
# (3.559026084010437, 22.26669161675249)

# %%
np.var(A),np.var(B)
# Out:
# (12.666666666666666, 495.8055555555556)

# %%
dataset["age"].var()
dataset["age"].std()
# Out:
# 14.526497332334044

# %%
sns.histplot(x="age",data=dataset)
plt.show()
